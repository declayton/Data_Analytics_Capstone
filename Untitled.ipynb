# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
stats = pd.read_csv('advance_stats.csv', encoding='cp1252')

# %%
stats.describe()
# Out:
#                 G           W           L        W-L%         SRS         SOS  \
# count  363.000000  363.000000  363.000000  363.000000  363.000000  363.000000
# mean    32.881543   17.118457   15.763085    0.514309   -0.558926   -0.259642
# std      2.035531    6.248073    4.967748    0.166116    9.665765    5.457077
# min     24.000000    3.000000    4.000000    0.094000  -24.460000  -11.170000
# 25%     32.000000   13.000000   12.000000    0.394000   -8.065000   -4.490000
# 50%     33.000000   17.000000   16.000000    0.516000   -1.500000   -1.620000
# 75%     34.000000   22.000000   19.000000    0.632500    6.020000    4.760000
# max     39.000000   35.000000   29.000000    0.897000   23.190000   11.840000
#
#             Tpoint  Avg Tpoint       Opoint  Avg Opoint  ...        3PAr  \
# count   363.000000  363.000000   363.000000  363.000000  ...  363.000000
# mean   2358.730028   71.621488  2305.209366   70.196694  ...    0.374322
# ...

# %%
stats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 363 entries, 0 to 362
# Data columns (total 23 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   School      363 non-null    object
#  1   G           363 non-null    int64
#  2   W           363 non-null    int64
#  3   L           363 non-null    int64
#  4   W-L%        363 non-null    float64
#  5   SRS         363 non-null    float64
#  6   SOS         363 non-null    float64
#  7   Tpoint      363 non-null    int64
#  8   Avg Tpoint  363 non-null    float64
#  9   Opoint      363 non-null    int64
#  10  Avg Opoint  363 non-null    float64
#  11  ORtg        363 non-null    float64
#  12  FTr         363 non-null    float64
#  13  3PAr        363 non-null    float64
#  14  TS%         363 non-null    float64
#  15  TRB%        363 non-null    float64
#  16  AST%        363 non-null    float64
#  17  STL%        363 non-null    float64
#  18  BLK%        363 non-null    float64
# ...

# %%
stats.drop('School', inplace=True, axis=1)

# %%
stats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 363 entries, 0 to 362
# Data columns (total 22 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   G           363 non-null    int64
#  1   W           363 non-null    int64
#  2   L           363 non-null    int64
#  3   W-L%        363 non-null    float64
#  4   SRS         363 non-null    float64
#  5   SOS         363 non-null    float64
#  6   Tpoint      363 non-null    int64
#  7   Avg Tpoint  363 non-null    float64
#  8   Opoint      363 non-null    int64
#  9   Avg Opoint  363 non-null    float64
#  10  ORtg        363 non-null    float64
#  11  FTr         363 non-null    float64
#  12  3PAr        363 non-null    float64
#  13  TS%         363 non-null    float64
#  14  TRB%        363 non-null    float64
#  15  AST%        363 non-null    float64
#  16  STL%        363 non-null    float64
#  17  BLK%        363 non-null    float64
#  18  eFG%        363 non-null    float64
# ...

# %%
matrix = stats.corr().round(2)
sns.heatmap(matrix, annot=True)
plt.show()

# %%
sns.heatmap(stats.corr())
# Out:
# <Axes: >
