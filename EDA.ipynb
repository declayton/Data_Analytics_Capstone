# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
tournament = pd.read_csv('MNCAATourneyDetailedResults.csv')
season = pd.read_csv('MRegularSeasonDetailedResults.csv')
# stats = pd.read_csv('advance_stats.csv')

# %%
season.shape
# Out:
# (92832, 39)

# %%
season.head()
# Out:
#    Season  DayNum  WTeamID  WScore  LTeamID  LScore  NumOT  WFGM  WFGA   WFG%  \
# 0    2003      10     1104      68     1328      62      0    27    58  0.466
# 1    2003      10     1272      70     1393      63      0    26    62  0.419
# 2    2003      11     1266      73     1437      61      0    24    58  0.414
# 3    2003      11     1296      56     1457      50      0    18    38  0.474
# 4    2003      11     1400      77     1208      71      0    30    61  0.492
#
#    ...  LFTM  LFTA   LFT%  LOR  LDR  LAst  LTO  LStl  LBlk  LPF
# 0  ...    16    22  0.727   10   22     8   18     9     2   20
# 1  ...     9    20  0.450   20   25     7   12     8     6   16
# 2  ...    14    23  0.609   31   22     9   12     2     5   23
# 3  ...     8    15  0.533   17   20     9   19     4     3   23
# 4  ...    17    27  0.630   21   15    12   10     7     1   14
#
# [5 rows x 39 columns]

# %%
types = {'WFT%': np.float64, 'LFT%': np.float64}
season.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92832 entries, 0 to 92831
# Data columns (total 39 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Season   92832 non-null  int64
#  1   DayNum   92832 non-null  int64
#  2   WTeamID  92832 non-null  int64
#  3   WScore   92832 non-null  int64
#  4   LTeamID  92832 non-null  int64
#  5   LScore   92832 non-null  int64
#  6   NumOT    92832 non-null  int64
#  7   WFGM     92832 non-null  int64
#  8   WFGA     92832 non-null  int64
#  9   WFG%     92832 non-null  float64
#  10  WFGM3    92832 non-null  int64
#  11  WFGA3    92832 non-null  int64
#  12  WFG3%    92832 non-null  float64
#  13  WFTM     92832 non-null  int64
#  14  WFTA     92832 non-null  int64
#  15  WFT%     92832 non-null  float64
#  16  WOR      92832 non-null  int64
#  17  WDR      92832 non-null  int64
#  18  WAst     92832 non-null  int64
#  19  WTO      92832 non-null  int64
#  20  WStl     92832 non-null  int64
# ...

# %%
season.describe()
# Out:
#              Season        DayNum       WTeamID        WScore       LTeamID  \
# count  92832.000000  92832.000000  92832.000000  92832.000000  92832.000000
# mean    2011.753178     70.836683   1287.254330     75.472499   1281.808396
# std        5.129266     35.588246    104.810567     11.100571    104.016540
# min     2003.000000      0.000000   1101.000000     34.000000   1101.000000
# 25%     2007.000000     40.000000   1198.000000     68.000000   1191.000000
# 50%     2012.000000     73.000000   1286.000000     75.000000   1280.000000
# 75%     2016.000000    101.000000   1379.000000     82.000000   1373.000000
# max     2020.000000    132.000000   1467.000000    144.000000   1467.000000
#
#              LScore         NumOT          WFGM          WFGA          WFG%  \
# count  92832.000000  92832.000000  92832.000000  92832.000000  92832.000000
# mean      63.483335      0.068425     26.147794     55.282521      0.474452
# ...

# %%
season.WScore.value_counts()
# Out:
# WScore
# 74     3453
# 73     3434
# 75     3406
# 76     3379
# 77     3298
#        ...
# 142       1
# 144       1
# 34        1
# 36        1
# 143       1
# Name: count, Length: 103, dtype: int64

# %%
plt.matshow(season.corr())
plt.show()

# %%
sns.heatmap(season.corr())
# Out:
# <Axes: >
