# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
stats = pd.read_csv('RegularSeasonStats.csv')

# %%
stats.shape
# Out:
# (92832, 13)

# %%
stats.head()
# Out:
#    Season  WTeamID  WScore  LTeamID  LScore   WTS%   WFG%  WFG3%   WFT%  \
# 0    2003     1104      68     1328      62  0.425  0.466  0.214  0.611
# 1    2003     1272      70     1393      63  0.387  0.419  0.400  0.526
# 2    2003     1266      73     1437      61  0.411  0.414  0.444  0.586
# 3    2003     1296      56     1457      50  0.462  0.474  0.333  0.548
# 4    2003     1400      77     1208      71  0.477  0.492  0.429  0.846
#
#     LTS%   LFG%  LFG3%   LFT%
# 0  0.427  0.415  0.200  0.727
# 1  0.316  0.358  0.250  0.450
# 2  0.280  0.301  0.115  0.609
# 3  0.322  0.367  0.273  0.533
# 4  0.395  0.387  0.375  0.630

# %%
stats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92832 entries, 0 to 92831
# Data columns (total 13 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Season   92832 non-null  int64
#  1   WTeamID  92832 non-null  int64
#  2   WScore   92832 non-null  int64
#  3   LTeamID  92832 non-null  int64
#  4   LScore   92832 non-null  int64
#  5   WTS%     92832 non-null  float64
#  6   WFG%     92832 non-null  float64
#  7   WFG3%    92832 non-null  float64
#  8   WFT%     92832 non-null  float64
#  9   LTS%     92832 non-null  float64
#  10  LFG%     92832 non-null  float64
#  11  LFG3%    92832 non-null  float64
#  12  LFT%     92832 non-null  float64
# dtypes: float64(8), int64(5)
# memory usage: 9.2 MB

# %%
stats.describe()
# Out:
#              Season       WTeamID        WScore       LTeamID        LScore  \
# count  92832.000000  92832.000000  92832.000000  92832.000000  92832.000000
# mean    2011.753178   1287.254330     75.472499   1281.808396     63.483335
# std        5.129266    104.810567     11.100571    104.016540     10.940956
# min     2003.000000   1101.000000     34.000000   1101.000000     20.000000
# 25%     2007.000000   1198.000000     68.000000   1191.000000     56.000000
# 50%     2012.000000   1286.000000     75.000000   1280.000000     63.000000
# 75%     2016.000000   1379.000000     82.000000   1373.000000     70.000000
# max     2020.000000   1467.000000    144.000000   1467.000000    140.000000
#
#                WTS%          WFG%         WFG3%          WFT%          LTS%  \
# count  92832.000000  92832.000000  92832.000000  92832.000000  92832.000000
# mean       0.452416      0.474452      0.380764      0.710174      0.379869
# ...

# %%
plt.matshow(stats.corr())

plt.show()

# %%
sns.heatmap(stats.corr())
# Out:
# <Axes: >

# %%
matrix = stats.corr().round(2)
sns.heatmap(matrix, annot=True)
plt.show()
